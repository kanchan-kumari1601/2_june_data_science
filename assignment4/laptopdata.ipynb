# %% [markdown]
# ## laptop_data_cleaned.csv

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\ASUS\Downloads\laptop_data_cleaned.csv")

# %%
df
# Out:
#      Company            TypeName  Ram  Weight      Price  TouchScreen  Ips  \
# 0      Apple           Ultrabook    8    1.37  11.175755            0    1
# 1      Apple           Ultrabook    8    1.34  10.776777            0    0
# 2         HP            Notebook    8    1.86  10.329931            0    0
# 3      Apple           Ultrabook   16    1.83  11.814476            0    1
# 4      Apple           Ultrabook    8    1.37  11.473101            0    1
# ...      ...                 ...  ...     ...        ...          ...  ...
# 1268    Asus            Notebook    4    2.20  10.555257            0    0
# 1269  Lenovo  2 in 1 Convertible    4    1.80  10.433899            1    1
# 1270  Lenovo  2 in 1 Convertible   16    1.30  11.288115            1    1
# 1271  Lenovo            Notebook    2    1.50   9.409283            0    0
# 1272      HP            Notebook    6    2.19  10.614129            0    0
#
# ...

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight      Price  TouchScreen  Ips         Ppi  \
# 0   Apple  Ultrabook    8    1.37  11.175755            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34  10.776777            0    0  127.677940
# 2      HP   Notebook    8    1.86  10.329931            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  11.814476            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37  11.473101            0    1  226.983005
#
#        Cpu_brand  HDD  SSD Gpu_brand      Os
# 0  Intel Core i5    0  128     Intel     Mac
# 1  Intel Core i5    0    0     Intel     Mac
# 2  Intel Core i5    0  256     Intel  Others
# 3  Intel Core i7    0  512       AMD     Mac
# 4  Intel Core i5    0  256     Intel     Mac

# %%
df.tail()
# Out:
#      Company            TypeName  Ram  Weight      Price  TouchScreen  Ips  \
# 1268    Asus            Notebook    4    2.20  10.555257            0    0
# 1269  Lenovo  2 in 1 Convertible    4    1.80  10.433899            1    1
# 1270  Lenovo  2 in 1 Convertible   16    1.30  11.288115            1    1
# 1271  Lenovo            Notebook    2    1.50   9.409283            0    0
# 1272      HP            Notebook    6    2.19  10.614129            0    0
#
#              Ppi              Cpu_brand   HDD  SSD Gpu_brand       Os
# 1268  100.454670          Intel Core i7   500    0    Nvidia  Windows
# 1269  157.350512          Intel Core i7     0  128     Intel  Windows
# 1270  276.053530          Intel Core i7     0  512     Intel  Windows
# 1271  111.935204  Other Intel Processor     0    0     Intel  Windows
# 1272  100.454670          Intel Core i7  1000    0       AMD  Windows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1273 entries, 0 to 1272
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1273 non-null   object
#  1   TypeName     1273 non-null   object
#  2   Ram          1273 non-null   int64
#  3   Weight       1273 non-null   float64
#  4   Price        1273 non-null   float64
#  5   TouchScreen  1273 non-null   int64
#  6   Ips          1273 non-null   int64
#  7   Ppi          1273 non-null   float64
#  8   Cpu_brand    1273 non-null   object
#  9   HDD          1273 non-null   int64
#  10  SSD          1273 non-null   int64
#  11  Gpu_brand    1273 non-null   object
#  12  Os           1273 non-null   object
# dtypes: float64(3), int64(5), object(5)
# memory usage: 129.4+ KB

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Ram', 'Weight', 'Price', 'TouchScreen', 'Ips',
#        'Ppi', 'Cpu_brand', 'HDD', 'SSD', 'Gpu_brand', 'Os'],
#       dtype='object')

# %%
df.describe()
# Out:
#                Ram       Weight        Price  TouchScreen          Ips  \
# count  1273.000000  1273.000000  1273.000000  1273.000000  1273.000000
# mean      8.447761     2.041100    10.828218     0.146897     0.279654
# std       5.098771     0.669241     0.619565     0.354142     0.449006
# min       2.000000     0.690000     9.134616     0.000000     0.000000
# 25%       4.000000     1.500000    10.387379     0.000000     0.000000
# 50%       8.000000     2.040000    10.872255     0.000000     0.000000
# 75%       8.000000     2.310000    11.287447     0.000000     1.000000
# max      64.000000     4.700000    12.691441     1.000000     1.000000
#
#                Ppi          HDD          SSD
# count  1273.000000  1273.000000  1273.000000
# mean    146.950812   413.715632   186.252946
# std      42.926775   518.054486   186.531571
# min      90.583402     0.000000     0.000000
# 25%     127.335675     0.000000     0.000000
# 50%     141.211998     0.000000   256.000000
# ...

# %%
df.isnull()
# Out:
#       Company  TypeName    Ram  Weight  Price  TouchScreen    Ips    Ppi  \
# 0       False     False  False   False  False        False  False  False
# 1       False     False  False   False  False        False  False  False
# 2       False     False  False   False  False        False  False  False
# 3       False     False  False   False  False        False  False  False
# 4       False     False  False   False  False        False  False  False
# ...       ...       ...    ...     ...    ...          ...    ...    ...
# 1268    False     False  False   False  False        False  False  False
# 1269    False     False  False   False  False        False  False  False
# 1270    False     False  False   False  False        False  False  False
# 1271    False     False  False   False  False        False  False  False
# 1272    False     False  False   False  False        False  False  False
#
#       Cpu_brand    HDD    SSD  Gpu_brand     Os
# ...

# %%
df.isnull().sum()
# Out:
# Company        0
# TypeName       0
# Ram            0
# Weight         0
# Price          0
# TouchScreen    0
# Ips            0
# Ppi            0
# Cpu_brand      0
# HDD            0
# SSD            0
# Gpu_brand      0
# Os             0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1268    False
# 1269    False
# 1270    False
# 1271    False
# 1272    False
# Length: 1273, dtype: bool

# %%
df=df.dropna()

# %%
df =df.drop(['TypeName','Cpu_brand','Gpu_brand'], axis=1 )

# %%
df
# Out:
#      Company  Ram  Weight      Price  TouchScreen  Ips         Ppi   HDD  SSD  \
# 0      Apple    8    1.37  11.175755            0    1  226.983005     0  128
# 1      Apple    8    1.34  10.776777            0    0  127.677940     0    0
# 2         HP    8    1.86  10.329931            0    0  141.211998     0  256
# 3      Apple   16    1.83  11.814476            0    1  220.534624     0  512
# 4      Apple    8    1.37  11.473101            0    1  226.983005     0  256
# ...      ...  ...     ...        ...          ...  ...         ...   ...  ...
# 1268    Asus    4    2.20  10.555257            0    0  100.454670   500    0
# 1269  Lenovo    4    1.80  10.433899            1    1  157.350512     0  128
# 1270  Lenovo   16    1.30  11.288115            1    1  276.053530     0  512
# 1271  Lenovo    2    1.50   9.409283            0    0  111.935204     0    0
# 1272      HP    6    2.19  10.614129            0    0  100.454670  1000    0
#
#            Os
# 0         Mac
# ...

# %%
cat_col=df.select_dtypes(include='object')
cat_col
# Out:
#      Company       Os
# 0      Apple      Mac
# 1      Apple      Mac
# 2         HP   Others
# 3      Apple      Mac
# 4      Apple      Mac
# ...      ...      ...
# 1268    Asus  Windows
# 1269  Lenovo  Windows
# 1270  Lenovo  Windows
# 1271  Lenovo  Windows
# 1272      HP  Windows
#
# [1273 rows x 2 columns]

# %%
df['Company'].unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'Chuwi', 'MSI',
#        'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %%
company_dict={'Apple':1, 'HP':2, 'Acer':3, 'Asus':4, 'Dell':5, 'Lenovo':6, 'Chuwi':7, 'MSI':8,
       'Microsoft':9, 'Toshiba':10, 'Huawei':11, 'Xiaomi':12, 'Vero':13, 'Razer':14,
       'Mediacom':15, 'Samsung':16, 'Google':17, 'Fujitsu':18, 'LG':19}

# %%
company_dict
# Out:
# {'Apple': 1,
#  'HP': 2,
#  'Acer': 3,
#  'Asus': 4,
#  'Dell': 5,
#  'Lenovo': 6,
#  'Chuwi': 7,
#  'MSI': 8,
#  'Microsoft': 9,
#  'Toshiba': 10,
#  'Huawei': 11,
#  'Xiaomi': 12,
#  'Vero': 13,
#  'Razer': 14,
#  'Mediacom': 15,
#  'Samsung': 16,
#  'Google': 17,
#  'Fujitsu': 18,
#  'LG': 19}

# %%
df['Company']=df['Company'].map(company_dict)

# %%
df
# Out:
#       Company  Ram  Weight      Price  TouchScreen  Ips         Ppi   HDD  \
# 0           1    8    1.37  11.175755            0    1  226.983005     0
# 1           1    8    1.34  10.776777            0    0  127.677940     0
# 2           2    8    1.86  10.329931            0    0  141.211998     0
# 3           1   16    1.83  11.814476            0    1  220.534624     0
# 4           1    8    1.37  11.473101            0    1  226.983005     0
# ...       ...  ...     ...        ...          ...  ...         ...   ...
# 1268        4    4    2.20  10.555257            0    0  100.454670   500
# 1269        6    4    1.80  10.433899            1    1  157.350512     0
# 1270        6   16    1.30  11.288115            1    1  276.053530     0
# 1271        6    2    1.50   9.409283            0    0  111.935204     0
# 1272        2    6    2.19  10.614129            0    0  100.454670  1000
#
#       SSD       Os
# 0     128      Mac
# 1       0      Mac
# ...

# %%
df['Os'].unique()
# Out:
# array(['Mac', 'Others', 'Windows'], dtype=object)

# %%
Os_dict={'Mac':0, 'Others':1, 'Windows':2}

# %%
df['Os']=df['Os'].map(Os_dict)

# %%
df
# Out:
#       Company  Ram  Weight      Price  TouchScreen  Ips         Ppi   HDD  \
# 0           1    8    1.37  11.175755            0    1  226.983005     0
# 1           1    8    1.34  10.776777            0    0  127.677940     0
# 2           2    8    1.86  10.329931            0    0  141.211998     0
# 3           1   16    1.83  11.814476            0    1  220.534624     0
# 4           1    8    1.37  11.473101            0    1  226.983005     0
# ...       ...  ...     ...        ...          ...  ...         ...   ...
# 1268        4    4    2.20  10.555257            0    0  100.454670   500
# 1269        6    4    1.80  10.433899            1    1  157.350512     0
# 1270        6   16    1.30  11.288115            1    1  276.053530     0
# 1271        6    2    1.50   9.409283            0    0  111.935204     0
# 1272        2    6    2.19  10.614129            0    0  100.454670  1000
#
#       SSD  Os
# 0     128   0
# 1       0   0
# 2     256   1
# 3     512   0
# ...

# %%
num_cal=df.select_dtypes(exclude='object')

# %%
num_cal
# Out:
#       Company  Ram  Weight      Price  TouchScreen  Ips         Ppi   HDD  \
# 0           1    8    1.37  11.175755            0    1  226.983005     0
# 1           1    8    1.34  10.776777            0    0  127.677940     0
# 2           2    8    1.86  10.329931            0    0  141.211998     0
# 3           1   16    1.83  11.814476            0    1  220.534624     0
# 4           1    8    1.37  11.473101            0    1  226.983005     0
# ...       ...  ...     ...        ...          ...  ...         ...   ...
# 1268        4    4    2.20  10.555257            0    0  100.454670   500
# 1269        6    4    1.80  10.433899            1    1  157.350512     0
# 1270        6   16    1.30  11.288115            1    1  276.053530     0
# 1271        6    2    1.50   9.409283            0    0  111.935204     0
# 1272        2    6    2.19  10.614129            0    0  100.454670  1000
#
#       SSD  Os
# 0     128   0
# 1       0   0
# 2     256   1
# 3     512   0
# ...

# %%
X = df.drop("Price", axis=1)
y = df[["Price"]]

# %%
X
# Out:
#       Company  Ram  Weight  TouchScreen  Ips         Ppi   HDD  SSD  Os
# 0           1    8    1.37            0    1  226.983005     0  128   0
# 1           1    8    1.34            0    0  127.677940     0    0   0
# 2           2    8    1.86            0    0  141.211998     0  256   1
# 3           1   16    1.83            0    1  220.534624     0  512   0
# 4           1    8    1.37            0    1  226.983005     0  256   0
# ...       ...  ...     ...          ...  ...         ...   ...  ...  ..
# 1268        4    4    2.20            0    0  100.454670   500    0   2
# 1269        6    4    1.80            1    1  157.350512     0  128   2
# 1270        6   16    1.30            1    1  276.053530     0  512   2
# 1271        6    2    1.50            0    0  111.935204     0    0   2
# 1272        2    6    2.19            0    0  100.454670  1000    0   2
#
# [1273 rows x 9 columns]

# %%
y
# Out:
#           Price
# 0     11.175755
# 1     10.776777
# 2     10.329931
# 3     11.814476
# 4     11.473101
# ...         ...
# 1268  10.555257
# 1269  10.433899
# 1270  11.288115
# 1271   9.409283
# 1272  10.614129
#
# [1273 rows x 1 columns]

# %% [markdown]
# ## Linear Regression

# %%
# !pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((1018, 9), (255, 9), (1018, 1), (255, 1))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
model=LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Training score:-",model.score(X_train,y_train))
# Out:
# Training score:- 0.618113464167103

# %%
print("Testing score:-",model.score(X_test,y_test))
# Out:
# Testing score:- 0.5951986757162591

# %%
pred=model.predict(X_test)

# %%
pred=pred.ravel()

# %%
import numpy as np
import pandas as pd

# %%
y_test=np.array(y_test).ravel()

# %%
history=pd.DataFrame({"predicted":pred,"actual":y_test})

# %%
history
# Out:
#      predicted     actual
# 0    11.254370  11.470547
# 1    10.637638  10.510802
# 2    10.829470  10.977717
# 3    10.935405  10.977717
# 4    10.298574  10.452533
# ..         ...        ...
# 250  10.826675  11.288115
# 251  10.482094  10.539417
# 252  11.238404  11.224776
# 253  11.305776  11.470547
# 254  10.456614  10.060060
#
# [255 rows x 2 columns]

# %%
import joblib
joblib.dump(model,'linear_regression_model')
# Out:
# ['linear_regression_model']

# %%
model =joblib.load('linear_regression_model')

# %%
model.predict(X_test)
# Out:
# array([[11.25436997],
#        [10.63763754],
#        [10.82947041],
#        [10.9354054 ],
#        [10.2985737 ],
#        [11.57131572],
#        [11.31123878],
#        [10.8892704 ],
#        [10.86316538],
#        [10.62560393],
#        [10.70874252],
#        [11.22741841],
#        [10.87065571],
#        [10.30530195],
#        [10.27958808],
#        [10.5745141 ],
#        [11.1526747 ],
#        [10.91257658],
#        [10.31818967],
#        [10.10619666],
#        [11.29145513],
#        [10.29015904],
#        [10.2963181 ],
#        [10.56357308],
#        [10.53309675],
#        [11.15741803],
#        [10.8587253 ],
#        [11.4390608 ],
#        [10.5526924 ],
#        [10.66195511],
#        [10.72974248],
#        [11.36996913],
#        [10.95516106],
#        [11.28894817],
#        [10.90509322],
#        [10.56473593],
#        [10.29015904],
#        [10.34736726],
#        [10.64192817],
#        [10.22141239],
#        [10.44832395],
# ...
